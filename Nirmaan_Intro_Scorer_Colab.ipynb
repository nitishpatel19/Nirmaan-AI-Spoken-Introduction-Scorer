# %% [markdown]
# # Nirmaan AI – Intro Scorer (Colab mini)
#
# Yahan aap `scoring.py` import karke transcripts score kar sakte ho.

# %%
# !pip install -q pandas openpyxl
print('Ready to import scoring.py')
# Out:
# Ready to import scoring.py

# %%
from scoring import evaluate_transcript
import json

sample = """Hello everyone, myself Muskan, studying in class 8th B section from Christ Public School.
I am 13 years old. I live with my family. There are 3 people in my family, me, my mother and my father.
One special thing about my family is that they are very kind hearted to everyone and soft spoken. One thing I really enjoy is play, playing cricket and taking wickets.
A fun fact about me is that I see in mirror and talk by myself. One thing people don't know about me is that I once stole a toy from one of my cousin.
 My favorite subject is science because it is very interesting. Through science I can explore the whole world and make the discoveries and improve the lives of others.
Thank you for listening."""
res = evaluate_transcript(sample, duration_seconds=60)
print(json.dumps(res, indent=2))
# Out:
# {
#   "overall_score": 68.89,
#   "max_score": 100.0,
#   "criteria": [
#     {
#       "name": "Salutation quality",
#       "max_score": 5,
#       "score": 2,
#       "details": {
#         "tier": "normal",
#         "matched_phrase": "hello "
#       },
#       "score_normalized_0_1": 0.4
#     },
#     {
#       "name": "Core details (must-have keywords)",
#       "max_score": 20,
#       "score": 16,
#       "details": {
#         "slots": {
#           "name": true,
#           "age": true,
#           "class_or_grade": true,
#           "school": true,
#           "hobbies_or_interests_or_goals": false
#         }
#       },
#       "score_normalized_0_1": 0.8
#     },
#     {
#       "name": "Additional flavour (good-to-have details)",
#       "max_score": 10,
#       "score": 4,
#       "details": {
#         "slots": {
#           "family_background": true,
#           "origin_location": false,
#           "thanks_or_closing": true,
#           "school_highlights": false,
#           "extra_curricular": false
#         }
#       },
#       "score_normalized_0_1": 0.4
#     },
#     {
#       "name": "Flow / structure",
#       "max_score": 5,
#       "score": 0,
#       "details": {
#         "stage_positions": {
#           "salutation": 0,
#           "name": 91,
#           "basic_details": 43,
#           "family_or_origin": 122,
#           "hobbies_or_goals": null
#         },
#         "is_ordered": false
#       },
#       "score_normalized_0_1": 0.0
#     },
#     {
#       "name": "Speech rate (WPM)",
#       "max_score": 10,
#       "score": 10.0,
#       "details": {
#         "wpm": 131.0,
#         "bucket": "111\u2013140"
#       },
#       "score_normalized_0_1": 1.0
#     },
#     {
#       "name": "Vocabulary richness (Type\u2013Token Ratio)",
#       "max_score": 10,
#       "score": 6.0,
#       "details": {
#         "ttr": 0.641,
#         "bucket": "0.5\u20130.69"
#       },
#       "score_normalized_0_1": 0.6
#     },
#     {
#       "name": "Clarity (filler words)",
#       "max_score": 15,
#       "score": 15.0,
#       "details": {
#         "filler_count": 0,
#         "rate_per_100_words": 0.0,
#         "bucket": "0\u20133"
#       },
#       "score_normalized_0_1": 1.0
#     },
#     {
#       "name": "Engagement / positivity",
#       "max_score": 15,
#       "score": 9.0,
#       "details": {
#         "positivity_index_0_1": 0.5,
#         "bucket": "0.5\u20130.69",
#         "positive_hits": 0,
#         "negative_hits": 0
#       },
#       "score_normalized_0_1": 0.6
#     }
#   ],
#   "meta": {
#     "word_count": 131,
#     "duration_seconds": 60,
#     "raw_total": 62.0,
#     "raw_max": 90
#   }
# }
